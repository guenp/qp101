# %%
from grove.tomography.state_tomography import do_state_tomography
from pyquil.quil import Program
from pyquil.gates import H, CZ, X, CNOT
from pyquil.api import QPUConnection, get_devices, QVMConnection
# %matplotlib inline

program = Program()
program += H(0)
program += H(1)
program += CZ(0, 1)
program += H(1)

qvm = QVMConnection()
tomo, _, _ = do_state_tomography(program, nsamples=2000, cxn=qvm)
tomo.plot()
# Out:
# 100%|██████████| 4/4 [00:00<00:00,  9.74it/s]
# 100%|██████████| 4/4 [00:00<00:00,  4.22it/s]
# 100%|██████████| 16/16 [00:01<00:00, 16.26it/s]
#  12%|█▎        | 2/16 [00:00<00:03,  4.56it/s]
# job pCCDwIKCsygwhGSa is currently running
# 100%|██████████| 16/16 [00:03<00:00,  5.35it/s]

# %%
qpu = QPUConnection("8Q-Agave")
tomo, _, _ = do_state_tomography(program, nsamples=2000, cxn=qpu)
tomo.plot()
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 12.06it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# job ndMxyJQEBhfOGoeP is currently running
# job ndMxyJQEBhfOGoeP is currently running
#  25%|██▌       | 1/4 [00:04<00:12,  4.22s/it]
# job WyzDbxJtBsJocUhx is currently running
#  50%|█████     | 2/4 [00:05<00:06,  3.45s/it]
# job aVrFluwubCWymisR is currently running
#  75%|███████▌  | 3/4 [00:07<00:02,  2.80s/it]
# job quaPRgcjPstwQlro is currently running
# 100%|██████████| 4/4 [00:08<00:00,  2.33s/it]
# 100%|██████████| 16/16 [00:01<00:00, 11.92it/s]
#   6%|▋         | 1/16 [00:00<00:03,  4.48it/s]
# job SMYmBBMqMcrXMLlC is currently running
#  12%|█▎        | 2/16 [00:01<00:08,  1.56it/s]
# job fKitwHTyIOujYivg is currently running
#  19%|█▉        | 3/16 [00:02<00:09,  1.34it/s]
# job UVGFmCWprKRElvJi is currently running
#  25%|██▌       | 4/16 [00:04<00:11,  1.00it/s]
# job cpElrMtWwqJHaIdP is currently running
#  31%|███▏      | 5/16 [00:05<00:12,  1.12s/it]
# job SNZVthqDKsgtBwJt is currently running
#  38%|███▊      | 6/16 [00:07<00:13,  1.35s/it]
# job oTOPcdXuLLIorhsK is currently running
#  50%|█████     | 8/16 [00:10<00:09,  1.21s/it]
# job NVjZSNporpzpwJlg is currently running
#  56%|█████▋    | 9/16 [00:11<00:07,  1.08s/it]
# job SctAlrlpfzKgihaP is currently running
#  62%|██████▎   | 10/16 [00:12<00:07,  1.20s/it]
# job jHXoqOxEdJzrOwfG is currently running
#  69%|██████▉   | 11/16 [00:13<00:05,  1.18s/it]
# job XqOIVWmyEIWmaSZq is currently running
#  75%|███████▌  | 12/16 [00:15<00:05,  1.25s/it]
# job HYcyZqKDatURFAqu is currently running
#  81%|████████▏ | 13/16 [00:16<00:03,  1.21s/it]
# job FxnNjtgyEMicwWqO is currently running
#  88%|████████▊ | 14/16 [00:17<00:02,  1.23s/it]
# job CqhGWYQwufxWcxbU is currently running
#  94%|█████████▍| 15/16 [00:19<00:01,  1.58s/it]
# job SCSJWrucYyhcBTyA is currently running
# 100%|██████████| 16/16 [00:20<00:00,  1.22s/it]
